# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %matplotlib inline

# %% [markdown]
# Goals:
# * Train Random Forest Classifier
# * Observe what happens when we increase number of trees
# * Plot decision boundary

# %%
from sklearn.datasets import make_moons

X, y = make_moons(noise=.1, n_samples=20)
X_test, y_test = make_moons(noise=.1)
print(X.shape, y.shape)

plt.scatter(X[:,0], X[:,1], c=y)
# Out:
# (20, 2) (20,)

# %% [markdown]
# Fit and evaluate Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# define the model
rf = RandomForestClassifier()

# train
rf.fit(X, y)

# compute score on test datab
rf.score(X_test, y_test)
# Out:
# 0.99

# %%
# from sklearn.tree import plot_tree
# plot_tree(rf.)

# %% [markdown]
# ## Increase number of base classifiers
#
# During the lecture, we said that random forest does not overft, when we incerease number of trees. Let us check this statement on our toy dataset.

# %%
scores = []
tr = np.arange(1, 500, 10)

for n_trees in tr:
    rf = RandomForestClassifier(n_estimators=n_trees)
    rf.fit(X, y)

    sc = rf.score(X_test, y_test)
    scores.append(sc)

# %%
# plot score w.r.t. number of trees
plt.plot(tr, scores)

# %% [markdown]
# ## Plot decision boundary
#
# We've also mentioned that the decision boundary of the random forest is more smooth. Now we will check this statement as well and see how the boundary chages when we increase number of trees in the forest.

# %%
def get_grid(data):
    x_min, x_max = data[:, 0].min() - 1, data[:, 0].max() + 1
    y_min, y_max = data[:, 1].min() - 1, data[:, 1].max() + 1
    return np.meshgrid(np.arange(x_min, x_max, 0.01),
                         np.arange(y_min, y_max, 0.01))

x1, x2 = get_grid(X)

# %%
def plot_boundary(rf):
    # make predictions
    y_pred = rf.predict_proba(np.c_[x1.ravel(), x2.ravel()])[:,0]
    y_pred = y_pred.reshape(x1.shape)
    
    # plot
    plt.contourf(x1, x2, y_pred, cmap=plt.cm.RdYlBu, alpha=0.8)
    plt.scatter(X[:,0], X[:,1], c=y)
    plt.show()

# %%
tr = np.arange(1, 200, 50)
for n_trees in tr:
    # fit random forest
    rf = RandomForestClassifier(n_estimators=n_trees)
    rf.fit(X, y)
    # plot boudary
    plot_boundary(rf)

# %%
rf[:, 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/yukos/work/hse/mda_machine_learning/week6/part_1.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/yukos/work/hse/mda_machine_learning/week6/part_1.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> rf[:, 0]
#
# File ~/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_base.py:199, in BaseEnsemble.__getitem__(self, index)
#     197 def __getitem__(self, index):
#     198     """Return the index'th estimator in the ensemble."""
# --> 199     return self.estimators_[index]
#
# TypeError: list indices must be integers or slices, not tuple
